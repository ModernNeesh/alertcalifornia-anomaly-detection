# %%
import pandas as pd
import os

# %%
cv_results_df = pd.read_csv("outputs/cross_validation_results.csv")

# %%
cv_results_df
# Out:
#    Objective   Training Accuracy Mean   Training Accuracy STD  \
# 0    triplet                 0.994880                0.002039
# 1    deepsad                 0.907286                0.008082
# 2       hsad                 0.797849                0.013044
# 3      final                 0.995598                0.000558
# 4    triplet                 0.996077                0.000719
# 5    deepsad                 0.907935                0.008180
# 6       hsad                 0.797458                0.010988
# 7      final                 0.995407                0.001085
# 8    triplet                 0.995742                0.000412
# 9    deepsad                 0.915714                0.005412
# 10      hsad                 0.806538                0.017132
# 11     final                 0.996077                0.002127
#
#      Validation Accuracy Mean   Validation Accuracy STD   Recall Mean  \
# 0                    0.943541                  0.005580      0.946424
# ...

# %%
cv_results_df.groupby("Objective").mean()
# Out:
#            Training Accuracy Mean  Training Accuracy STD  \
# Objective
# deepsad                  0.910312               0.007225
# final                    0.995694               0.001257
# hsad                     0.800615               0.013722
# triplet                  0.995566               0.001057
#
#            Validation Accuracy Mean  Validation Accuracy STD  Recall Mean  \
# Objective
# deepsad                    0.893328                 0.016661     0.901195
# final                      0.945774                 0.005634     0.947147
# hsad                       0.728751                 0.023776     0.761836
# triplet                    0.944434                 0.004798     0.946851
#
#            Recall STD  Precision Mean  Precision STD  Final Train Accuracy  \
# Objective
# deepsad      0.012703        0.893328       0.016661              0.909232
# final        0.006296        0.945774       0.005634              0.995917
# ...
